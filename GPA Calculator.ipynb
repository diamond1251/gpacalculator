# %%
## details
full_details = {
                    "matric_no" :[],
                    "student_name" :[],
                    "gender" : [],
                    "phone_number":[],
                    "department":[],
                    "level": [],
                    "session":[],
                    "programe" : "BTECH",
                    "remark": "not cleared",
                    "course_code" : [],
                    "course" : [],
                    "units": [],
                    "score": [],
                    "grade" : [],
                    "points" : [], 
                    "remarks" : "PASSED",
                    "gpa" : [],
                    "position" : []
    
}



# inputing the credentials 
while True:
    matric_number = input("Enter your matric number: ")
    if matric_number.isdigit():
        full_details["matric_no"].append(matric_number)
        break
    else:
        print("Invalid Entry")

#name of the respondant
name = input("Enter your full name: ").upper()
full_details["student_name"].append(name)


# gender
while True:
    sex = input("Enter your Gender: ").upper()
    if sex in ["MALE", "FEMALE"]:
        full_details["gender"].append(sex)
        break
    else:
        print("invalid Entry")
        

#telphone number
while True:
    tel = input("Enter your phone number: ")
    if tel.isdigit() and len(tel) == 11:
        full_details["phone_number"].append(tel)
        break
    else:
        print("Invalid entry!!! Enter a valid number")


#department
while True: 
    dept = input("Enter your department: ").upper()
    if dept.isdigit():
        print("Invalid Entry!!!! Try again")
    else:
        full_details["department"].append(dept)
        break


#level of the respondant
while True:
    lvl = input("Enter your Level: ")
    if lvl in ["100", "200", "300", "400", "500"]:
        full_details["level"].append(lvl)
        break
    else:
        print("Invalid Entry!!!! Try again")

        
# session of the semester
while True:
    year = input("Enter the session: RAIN/HARMATTAN ").upper()
    if year in ["RAIN", "HARMATTAN"]:
        full_details["session"].append(year)
        break
    else:
        print("Invalid Entry!!!! Try again")
        

# gpa calculator
def gpa():
    value = 0
    while True:
        grade = int(input("Enter your grade: "))
        if grade >=70 and grade <=100:
            value +=5
            full_details["score"].append(grade)
            grade_value = "A"
            full_details["grade"].append(grade_value)
            break
        elif grade >= 60 and grade <= 69:
            value +=4
            full_details["score"].append(grade)
            grade_value = "B"
            full_details["grade"].append(grade_value)
            break
        elif grade >= 50 and grade <=59:
            value +=3
            full_details["score"].append(grade)
            grade_value = "C"
            full_details["grade"].append(grade_value)
            break
        elif grade >= 45 and grade <= 49:
            value += 2
            full_details["score"].append(grade)
            grade_value = "D"
            full_details["grade"].append(grade_value)
            break
        elif grade >= 40 and grade <= 44:
            value += 1
            full_details["score"].append(grade)
            grade_value = "E"
            full_details["grade"].append(grade_value)
            break
        elif grade >=0 and grade <= 39:
            value +=0
            full_details["score"].append(grade)
            grade_value = "F"
            full_details["grade"].append(grade_value)
            break

        else:
            print("Invalid Entry!!!! Try again")



    unit_point = 0
    while True:
        unit = int(input("Enter the unit of the course: "))
        if unit in [0, 1, 2, 3, 4, 5]:
            unit_point = unit
            full_details["units"].append(unit)
            break
        else:
            print("Invalid Entry!!!! Try again")

        
    value_point = value*unit_point 
    full_details["points"].append(value_point)
    return (value*unit_point)/unit_point

#courses and course code

average_gpa = 0
for i in range (1,5):
    courses = input("Enter the course: ").upper()
    full_details["course"].append(courses)

    courses_code = input("Enter the course codes: ").upper()
    full_details["course_code"].append(courses_code)
    
    result =  gpa()
    average_gpa += result
    
final_gpa = average_gpa/no_of_course
full_details["gpa"].append(final_gpa)


#position in class
positions = ""
if 4.5 <= final_gpa <= 5.0:
    positions = "First Class"
elif 3.5 <= final_gpa < 4.5:
    positions = "Second Class Upper"
elif 2.5 <= final_gpa < 3.5:
    positions = "Second Class Lower"
elif 1.5 <= final_gpa < 2.5:
    positions = "Third Class"
elif 1.0 <= final_gpa < 1.5:
    positions = "Pass"
elif 0 <= final_gpa < 1.0:
    positions = "Advise to Withdraw"
else:
    positions = "Invalid GPA"

full_details["position"].append(positions)    
    
#result template
print(f"""
*************************************************************************************************************************
                                LADOKE AKINYOLA UNIVERSITY OF TECHNOLOGY
                                DEPARTMENT OF {full_details['department'][0]}
                               {full_details['programe']} ({full_details['department'][0]})
                        
*************************************************************************************************************************
________________________________________________________________________________________________________________________
|                                       STUDENT STATEMENT OF RESULT                                                    |
|______________________________________________________________________________________________________________________|
|MATRIC NO: |{full_details['matric_no'][0]}           |STUDENT NAME: | {full_details['student_name'][0]}               |    
|___________|_________________________________________|________________________________________________________________|
| GENDER: | {full_details['gender'][0]} | PHONE NUMBER: | {full_details['phone_number'][0]}                            |
|_________|_____________________________|_______________|______________________________________________________________|
|LEVEL:   | {full_details['level'][0]}  |SESSION:   | {full_details['session'][0]} SEMESTER                            |
|_________|_____________________________|___________|__________________________________________________________________|
|PROGRAME: | {"programe"}               |REMARK:    |{full_details['remark']}                                                        |
|__________|___________________________________________________________________________________________________________|
|                   {full_details['level'][0]} LEVEL, {full_details['session'][0]} SEMESTER                            |
|______________________________________________________________________________________________________________________|
|COURSE CODE                     | COURSE TITLE              |UNIT|SCORE|GRADE | POINT     |       REMARK              |
|________________________________|___________________________|____|_____|______|___________|___________________________|
| {full_details['course_code'][0]}| {full_details['course'][0]}| {full_details['units'][0]}| {full_details['score'][0]} | {full_details['grade'][0]}| {full_details['points'][0]} | {full_details['remarks']} |
|________________________________|___________________________|____|______|______|___________|__________________________|
| {full_details['course_code'][1]} | {full_details['course'][1]}| {full_details['units'][1]}| {full_details['score'][1]}| {full_details['grade'][1]}| {full_details['points'][1]} |{full_details['remarks']} |
|________________________________|___________________________|____|______|______|___________|__________________________|
| {full_details['course_code'][2]} | {full_details['course'][2]}| {full_details['units'][2]}| {full_details['score'][2]}| {full_details['grade'][2]}| {full_details['points'][2]} | {full_details['remarks']} |
|________________________________|___________________________|____|______|______|___________|__________________________|
| {full_details['course_code'][3]} | {full_details['course'][3]}| {full_details['units'][3]}| {full_details['score'][3]}| {full_details['grade'][3]}| {full_details['points'][3]} | {full_details['remarks']} |
|________________________________|___________________________|____|______|______|___________|__________________________|
|                    {full_details['session'][0]} SEMESTER PERFORMANCE                                                 |
|______________________________________________________________________________________________________________________|
| RAIN SEMESTER GPA :| {full_details['gpa'][0]}  | CLASS: |{full_details['position'][0]}                               |                                                                                                 |
|____________________|___________________________|________|____________________________________________________________|











""")
